# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# read in dataset and set columns
df = pd.read_csv('../../../Downloads/puzzle.csv', header = None)
df.columns = ['scaled_latitude','scaled_longitude']
# plot solution
ax = df.plot(kind = 'scatter', x = 'scaled_longitude', y = 'scaled_latitude', figsize = (16, 8))
plt.title("A map of a random sample of hopper's users or destinations???", size = 30)
plt.show()
